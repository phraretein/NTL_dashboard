# %%
import pandas as pd
import pymongo
from pymongo import MongoClient

# %%
# number of processed rows
n_processed = 0
# All counted
df_counted_all = pd.DataFrame(columns=["date", "organic", "ad", "ref link"])

# %%
def get_data_from_db():
  murl = "mongodb://heroku_m5rgq7gk:5qme114aruu0vdgk6821odskc3@ds211708.mlab.com:11708/heroku_m5rgq7gk"
  client = MongoClient(murl)
  dbname = 'heroku_m5rgq7gk'
  cl = client[dbname]
  ad_rec = cl.ad_id

  ad_customer = pd.DataFrame(list(ad_rec.find({})))
  # viewrec = viewrec[['Keyword','Intent']]
  return ad_customer

# %%
ad_users = get_data_from_db()

# %%
ad_users_real = ad_users.copy()

# %%
ad_users_real
# Out:
#                            _id         sender_id              ad_id ref  \
# 0     5ed11d5d942407c5f1c24131  2493839424063591  23843773285370141
# 1     5ed11d76f8434614ede0f2af  3077497682366125  23843773308040141
# 2     5ed12028f8434614ede0f2b0  3567881706561459  23843660144380141
# 3     5ed120f5f8434614ede0f2b1  3088913594523475  23844096090530141
# 4     5ed121fa942407c5f1c24133  3033464403393942  23844674975250721
# ...                        ...               ...                ...  ..
# 7625  5ef3012b2695496f680b4803  3102510433173257  23844810117260721
# 7626  5ef301649d279d01822f8da0  3589388924433028  23844963920220141
# 7627  5ef302712695496f680b4804  2806264476169150  23844963920270141
# 7628  5ef3037f2695496f680b4805  3072091579539036  23844809527100721
# 7629  5ef3048c9d279d01822f8da1  2914700285313105  23844810063080721
#
#                      date
# 0     2020-05-29 21:34:05
# 1     2020-05-29 21:34:30
# 2     2020-05-29 21:46:00
# 3     2020-05-29 21:49:25
# 4     2020-05-29 21:53:46
# ...                   ...
# 7625  2020-06-24 14:30:51
# 7626  2020-06-24 14:31:48
# 7627  2020-06-24 14:36:17
# 7628  2020-06-24 14:40:47
# 7629  2020-06-24 14:45:16
#
# [7630 rows x 5 columns]
